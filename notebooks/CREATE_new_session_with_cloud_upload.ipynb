# %% [markdown]
# # DataJoint Workflow Guide for Uploading Session Data to the Cloud

# %% [markdown]
# This notebook provides a walkthrough for uploading the data to the cloud.

# %% [markdown]
# **_Note:_**
#
# - The examples in this notebook use a sample dataset. Replace these entries with your actual database entries to access and analyze your data.

# %% [markdown]
# ### **Key Steps**
#
# - **Setup**
#
# - **Step 1: Initiate data upload**

# %% [markdown]
# ### **Setup**

# %% [markdown]
# Begin by importing the necessary libraries for the data pipeline and key schemas.

# %%
## Ensure the correct working directory

import os

if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

# %%
import datajoint as dj

# %%
from workflow.utils.initiate_session import upload_session_data

# %% [markdown]
# #### **Step 1: Initiate data upload**

# %% [markdown]
# ##### Example
#
# If the data is located at `/Users/milagros/Documents/data/organoids/inbox/21-24_raw/..`, where `local_outbox:"/Users/milagros/Documents/data/organoids/` in the `config.yaml`, then run:
#
# ```python
# upload_session_data('21-24_raw')
# ```

# %% [markdown]
# Proceed to upload the data to AWS S3 bucket:

# %%
upload_session_data("test2")
# Out:
# [2024-10-09 19:11:26,243][get_config][INFO]: Existing configuration detected. Loading from /Users/milagros/Library/Application Support/djsciops/config.yaml...
# [2024-10-09 19:11:26,244][_resolve_upload_mapping][INFO]: Resolving upload mapping...
# [2024-10-09 19:11:26,451][flush][INFO]: Total Uploading Progress:   0%|          | 0.00/4.00 [00:00<?, ?B/s]
# [2024-10-09 19:11:26,452][flush][INFO]:
# [2024-10-09 19:11:26,453][flush][INFO]: /Users/milagros/Documents/data/organoids/inbox/test2/test.txt->utah_organoids/inbox/test2/test.txt Progress:   0%|          | 0.00/4.00 [00:00<?, ?B/s]
# [2024-10-09 19:11:26,453][flush][INFO]:
# [2024-10-09 19:11:26,683][flush][INFO]: /Users/milagros/Documents/data/organoids/inbox/test2/test.txt->utah_organoids/inbox/test2/test.txt Progress: 100%|##########| 4.00/4.00 [00:00<00:00, 17.5B/s]
# [2024-10-09 19:11:26,684][flush][INFO]: Total Uploading Progress: 100%|##########| 4.00/4.00 [00:00<00:00, 17.2B/s]
# ...

# %%
# !djsciops config
# Out:
# [2024-10-09 19:10:32,433][get_config][INFO]: Existing configuration detected. Loading from /Users/milagros/Library/Application Support/djsciops/config.yaml...
# [2024-10-09 19:10:32,521][get_config][INFO]: Existing configuration detected. Loading from /Users/milagros/Library/Application Support/djsciops/config.yaml...
# aws:
#   account_id: '398726522705'
# boto3:
#   max_concurrency: 100
#   multipart_chunksize: 67108864
#   multipart_threshold: 67108864
#   use_threads: true
# djauth:
#   client_id: utah_organoids
#   client_secret: IewGAYQpVIeHKVamWVmTKqCom44ybJH4
#   issuer: https://accounts.datajoint.com/realms/datajoint
# s3:
#   bucket: dj-sciops
#   role: utah_organoids_researcher
# version: 1.5.8
